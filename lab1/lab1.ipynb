# %%
# %pip install opencv-python
# %pip install pillow
# Out:
# Requirement already satisfied: opencv-python in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from opencv-python) (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pillow in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (12.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
img=cv2.imread("forest.jpg")
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
from PIL import Image
img2 =Image.open("space.jpg")
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(img2, cmap = cm.Greys)
plt.show()

# %% [markdown]
# Task #3: Image Storing
# a.	Saving image to disc using OpenCV

# %%
cv2.imwrite('forest.jpg',img)
# Out:
# True

# %% [markdown]
# b.	Saving image to disc using PIL

# %%
img2.save('space1.jpg')

# %%
print(img.shape)
print(img)
# Out:
# (174, 290, 3)
# [[[148 197 169]
#   [132 177 150]
#   [ 97 133 109]
#   ...
#   [ 54  99  82]
#   [ 23  67  50]
#   [  6  48  31]]
#
#  [[ 79 128 100]
#   [ 73 118  91]
#   [ 85 121  97]
#   ...
#   [  6  50  33]
#   [ 35  72  56]
#   [ 20  56  40]]
#
#  [[ 95 146 119]
#   [ 94 141 115]
#   [120 159 134]
#   ...
#   [ 20  59  43]
#   [ 19  45  32]
#   [ 13  33  21]]
#
#  ...
#
#  [[  8  10  10]
#   [  8  10  10]
#   [  9  11  11]
#   ...
#   [ 69  69  87]
#   [ 80  80  96]
#   [ 76  75  91]]
#
#  [[  8  10  10]
#   [  8  10  10]
#   [  8  10  10]
#   ...
#   [ 59  59  75]
#   [ 86  86 104]
#   [ 73  73  91]]
#
#  [[  5   7   7]
#   [  6   8   8]
#   [  6   8   8]
#   ...
#   [ 39  39  55]
#   [ 42  42  60]
#   [ 21  21  39]]]

# %%
import numpy as np
img_arr=np.array(img2)
print(img_arr.shape)
print(img_arr)
# Out:
# (170, 296, 3)
# [[[  9  19  31]
#   [  9  19  31]
#   [  9  19  31]
#   ...
#   [  9  19  31]
#   [  9  19  31]
#   [  9  19  31]]
#
#  [[  9  19  31]
#   [  9  19  31]
#   [  9  19  31]
#   ...
#   [  9  19  31]
#   [  9  19  31]
#   [  9  19  31]]
#
#  [[  9  19  31]
#   [  9  19  31]
#   [  9  19  31]
#   ...
#   [  9  19  31]
#   [  9  19  31]
#   [  9  19  31]]
#
#  ...
#
#  [[ 59  94 126]
#   [ 62  97 129]
#   [ 73 108 138]
#   ...
#   [113 147 182]
#   [ 56  90 127]
#   [ 58  92 129]]
#
#  [[ 74 109 141]
#   [ 49  84 116]
#   [ 58  93 123]
#   ...
#   [168 198 232]
#   [138 168 204]
#   [ 74 107 142]]
#
#  [[ 57  92 124]
#   [ 40  75 107]
#   [ 44  79 109]
#   ...
#   [170 199 231]
#   [162 192 226]
#   [132 162 196]]]
